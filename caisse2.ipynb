# %%
from tkinter import *
import random
from reportlab.pdfgen import canvas
import mysql.connector

class caisse:
            
    def __init__(self,id_client=0,tel_client=0,no_tic_client=0):
        self.id_client=id_client
        self.tel_client=tel_client
        self.no_tic_client=no_tic_client
        
        self.db=mysql.connector.connect(
        host='localhost',
        user='rym',
        password='12345',
        database='gestion_patisserie'
        )
        self.mycursor=self.db.cursor()
    def ajoutercaisse(self):
        sql = 'INSERT INTO caisse1 (id_client, tel_client, no_tic_client) VALUES (%s, %s, %s)'
        val=(self.id_client,self.tel_client,self.no_tic_client)
        self.mycursor.execute(sql,val)
        self.db.commit()
        print(self.mycursor.rowcount,'record inserted.')







class Ticket_App:
    def __init__(self,root):
        self.root = root
        self.root.geometry("1300x700+0+0")
        self.root.maxsize(width = 1280,height = 700)
        self.root.minsize(width = 1280,height = 700)
        self.root.title("interface de tickets")
       
        #====================Variables========================#
        self.id_client = StringVar()
        self.tel_client = StringVar()
        #For Generating Random Bill Numbers
        x = random.randint(1000,9999)
        self.no_tic_client = StringVar()
        
        
        
        
        
        #Seting Value to variable
        self.no_tic_client.set(str(x))
        self.MILLEFEUILLE = IntVar()
        self.PARIS_BREST = IntVar()
        self.OPERA= IntVar()
        self.FRAISIER = IntVar()
        self.ECLAIR= IntVar()
        self.BAK = IntVar()
        self.Bambalouni = IntVar()
        self.Makroud = IntVar()
        self.Zlabia = IntVar()
        self.Bjawia = IntVar()
        self.jus = IntVar()
        self.boisson_gazeuse = IntVar()
        self.citronnade = IntVar()
        self.eau = IntVar()
        self.biscuits = IntVar()
        self.total_fran = StringVar()
        self.total_tuni = StringVar()
        self.total_autre = StringVar()
        self.tax_fran = StringVar()
        self.tax_tuni = StringVar()
        self.tax_autre = StringVar()
 
        
        
        
        
        


        #===================================
        bg_color = "#074463"
        fg_color = "white"
        lbl_color = 'white'
        #Title of App
        title = Label(self.root,text = "Caisse",bd = 12,relief = GROOVE,fg = fg_color,bg = bg_color,font=("times new roman",30,"bold"),pady = 3).pack(fill = X)

        #========== Frame des clients==========#
        F1 = LabelFrame(text = " Données des clients",font = ("time new roman",12,"bold"),fg = "gold",bg = bg_color,relief = GROOVE,bd = 10)
        F1.place(x = 0,y = 80,relwidth = 1)

        #===============ID CLIENT===========#
        cid_lbl = Label(F1,text="Id client",bg = bg_color,fg = fg_color,font=("times new roman",15,"bold")).grid(row = 0,column = 0,padx = 10,pady = 5)
        cid_en = Entry(F1,bd = 8,relief = GROOVE,textvariable = self.id_client)
        cid_en.grid(row = 0,column = 1,ipady = 4,ipadx = 30,pady = 5)

        #================= tel client ==============#
        ctel_lbl = Label(F1,text = "Phone No",bg = bg_color,fg = fg_color,font = ("times new roman",15,"bold")).grid(row = 0,column = 2,padx = 20)
        ctel_en = Entry(F1,bd = 8,relief = GROOVE,textvariable = self.tel_client)
        ctel_en.grid(row = 0,column = 3,ipady = 4,ipadx = 30,pady = 5)

        #====================numero du ticket client==================#
        cticket_lbl = Label(F1,text = "Nmero ticket",bg = bg_color,fg = fg_color,font = ("times new roman",15,"bold"))
        cticket_lbl.grid(row = 0,column = 4,padx = 20)
        cticket_en = Entry(F1,bd = 8,relief = GROOVE,textvariable = self.no_tic_client)
        cticket_en.grid(row = 0,column = 5,ipadx = 30,ipady = 4,pady = 5)
       
        #==================== Button rechercher ticket===============#
        ticket_btn = Button(F1,text = "Enter",bd = 7,relief = GROOVE,font = ("times new roman",12,"bold"),bg = bg_color,fg = fg_color,command=self.add)
        ticket_btn.grid(row = 0,column = 6,ipady = 5,padx = 60,ipadx = 19,pady = 5)

        #================== Frame PÂTISSERIE FRANÇAISE=====================#
        F2 = LabelFrame(self.root,text = 'Patisserie Française',bd = 10,relief = GROOVE,bg = bg_color,fg = "gold",font = ("times new roman",13,"bold"))
        F2.place(x = 5,y = 180,width = 325,height = 380)

        #===========Frame produits==============================
        paris_b_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "PARIS_BREST")
        paris_b_lbl.grid(row = 0,column = 0,padx = 10,pady = 20)
        paris_b_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.PARIS_BREST)
        paris_b_en.grid(row = 0,column = 1,ipady = 5,ipadx = 5)

        #======= ECLAIR

        eclair_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "ECLAIR")
        eclair_lbl.grid(row = 1,column = 0,padx = 10,pady = 20)
        eclair_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.ECLAIR)
        eclair_en.grid(row = 1,column = 1,ipady = 5,ipadx = 5)

        #========FRAISIER
        fraisier_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "FRAISIER")
        fraisier_lbl.grid(row = 2,column = 0,padx = 10,pady = 20)
        fraisier_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.FRAISIER)
        fraisier_en.grid(row = 2,column = 1,ipady = 5,ipadx = 5)

        #========OPERA
        opera_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "OPERA")
        opera_lbl.grid(row = 3,column = 0,padx = 10,pady = 20)
        opera_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.OPERA)
        opera_en.grid(row = 3,column = 1,ipady = 5,ipadx = 5)

        #============MILLEFEUILLE
        millefeuille_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "MILLEFEUILLE ")
        millefeuille_lbl.grid(row = 4,column = 0,padx = 10,pady = 20)
        millefeuille_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.MILLEFEUILLE )
        millefeuille_en.grid(row = 4,column = 1,ipady = 5,ipadx = 5)

        #==================Frame patisserie tunisienne=====================#
        F2 = LabelFrame(self.root,text = 'Patisserie Tunisienne',bd = 10,relief = GROOVE,bg = bg_color,fg = "gold",font = ("times new roman",13,"bold"))
        F2.place(x = 330,y = 180,width = 325,height = 380)

        #===========Frame Content
        BAK_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Baklawa El Bey")
        BAK_lbl.grid(row = 0,column = 0,padx = 10,pady = 20)
        BAK_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.BAK)
        BAK_en.grid(row = 0,column = 1,ipady = 5,ipadx = 5)

        #=======
        Makroud_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Makroud")
        Makroud_lbl.grid(row = 1,column = 0,padx = 10,pady = 20)
        Makroud_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.Makroud)
        Makroud_en.grid(row = 1,column = 1,ipady = 5,ipadx = 5)

        #=======
        Bambalouni_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Bambalouni")
        Bambalouni_lbl.grid(row = 2,column = 0,padx = 10,pady = 20)
        Bambalouni_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.Bambalouni)
        Bambalouni_en.grid(row = 2,column = 1,ipady = 5,ipadx = 5)

        #========
        Zlabia_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Zlabia")
        Zlabia_lbl.grid(row = 3,column = 0,padx = 10,pady = 20)
        Zlabia_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.Zlabia)
        Zlabia_en.grid(row = 3,column = 1,ipady = 5,ipadx = 5)

        #============
        Bjawia_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Bjawia")
        Bjawia_lbl.grid(row = 4,column = 0,padx = 10,pady = 20)
        Bjawia_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.Bjawia)
        Bjawia_en.grid(row = 4,column = 1,ipady = 5,ipadx = 5)

        #==================Autres=====================#

        F2 = LabelFrame(self.root,text = 'Autres',bd = 10,relief = GROOVE,bg = bg_color,fg = "gold",font = ("times new roman",13,"bold"))
        F2.place(x = 655,y = 180,width = 325,height = 380)

        #===========Frame Content
        jus_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Jus")
        jus_lbl.grid(row = 0,column = 0,padx = 10,pady = 20)
        jus_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.jus)
        jus_en.grid(row = 0,column = 1,ipady = 5,ipadx = 5)

        #=======
        cock_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Boisson gazeuse")
        cock_lbl.grid(row = 1,column = 0,padx = 10,pady = 20)
        cock_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.boisson_gazeuse)
        cock_en.grid(row = 1,column = 1,ipady = 5,ipadx = 5)

        #=======
        citronnade_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "citronnade")
        citronnade_lbl.grid(row = 2,column = 0,padx = 10,pady = 20)
        citronnade_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.citronnade)
        citronnade_en.grid(row = 2,column = 1,ipady = 5,ipadx = 5)

        #========
        cold_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "EAU")
        cold_lbl.grid(row = 3,column = 0,padx = 10,pady = 20)
        cold_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.eau)
        cold_en.grid(row = 3,column = 1,ipady = 5,ipadx = 5)

        #============
        bis_lbl = Label(F2,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Biscuits")
        bis_lbl.grid(row = 4,column = 0,padx = 10,pady = 20)
        bis_en = Entry(F2,bd = 8,relief = GROOVE,textvariable = self.biscuits)
        bis_en.grid(row = 4,column = 1,ipady = 5,ipadx = 5)

        #===================Bill Aera================#
        F3 = Label(self.root,bd = 10,relief = GROOVE)
        F3.place(x = 960,y = 180,width = 325,height = 380)
        #===========
        bill_title = Label(F3,text = "Zone de facturation",font = ("Lucida",13,"bold"),bd= 7,relief = GROOVE)
        bill_title.pack(fill = X)

        #============
        scroll_y = Scrollbar(F3,orient = VERTICAL)
        self.txt = Text(F3,yscrollcommand = scroll_y.set)
        scroll_y.pack(side = RIGHT,fill = Y)
        scroll_y.config(command = self.txt.yview)
        self.txt.pack(fill = BOTH,expand = 1)

        #===========Buttons Frame=============#
        F4 = LabelFrame(self.root,text = 'Menu de facturation',bd = 10,relief = GROOVE,bg = bg_color,fg = "gold",font = ("times new roman",13,"bold"))
        F4.place(x = 0,y = 560,relwidth = 1,height = 145)
        #===================
        fran_lbl = Label(F4,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Total Française")
        fran_lbl.grid(row = 0,column = 0,padx = 10,pady = 0)
        fran_en = Entry(F4,bd = 8,relief = GROOVE,textvariable = self.total_fran )
        fran_en.grid(row = 0,column = 1,ipady = 2,ipadx = 5)

        #===================
        gro_lbl = Label(F4,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Total Tunisienne")
        gro_lbl.grid(row = 1,column = 0,padx = 10,pady = 5)
        gro_en = Entry(F4,bd = 8,relief = GROOVE,textvariable = self.total_tuni)
        gro_en.grid(row = 1,column = 1,ipady = 2,ipadx = 5)

        #================
        oth_lbl = Label(F4,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Total Autres")
        oth_lbl.grid(row = 2,column = 0,padx = 10,pady = 5)
        oth_en = Entry(F4,bd = 8,relief = GROOVE,textvariable = self.total_autre)
        oth_en.grid(row = 2,column = 1,ipady = 2,ipadx = 5)

        #================
        fran_lbl = Label(F4,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Tax Française")
        fran_lbl.grid(row = 0,column = 2,padx = 30,pady = 0)
        fran_en = Entry(F4,bd = 8,relief = GROOVE,textvariable = self.tax_fran)
        fran_en.grid(row = 0,column = 3,ipady = 2,ipadx = 5)

        #=================
        grot_lbl = Label(F4,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = " Tax Tunisienne")
        grot_lbl.grid(row = 1,column = 2,padx = 30,pady = 5)
        grot_en = Entry(F4,bd = 8,relief = GROOVE,textvariable = self.tax_tuni)
        grot_en.grid(row = 1,column = 3,ipady = 2,ipadx = 5)

        #==================
        otht_lbl = Label(F4,font = ("times new roman",15,"bold"),fg = lbl_color,bg = bg_color,text = "Tax Autres")
        otht_lbl.grid(row = 2,column = 2,padx = 10,pady = 5)
        otht_en = Entry(F4,bd = 8,relief = GROOVE,textvariable = self.tax_autre)
        otht_en.grid(row = 2,column = 3,ipady = 2,ipadx = 5)

        #====================
        total_btn = Button(F4,text = "Total",bg = bg_color,fg = fg_color,font=("lucida",12,"bold"),bd = 7,relief = GROOVE,command = self.total)
        total_btn.grid(row = 1,column = 4,ipadx = 20,padx = 30)
        #========================
        genbill_btn = Button(F4,text = "Generer ",bg = bg_color,fg = fg_color,font=("lucida",12,"bold"),bd = 7,relief = GROOVE,command = self.bill_area)
        genbill_btn.grid(row = 1,column = 5,ipadx = 20)

        #====================
        clear_btn = Button(F4,text = "Effacer",bg = bg_color,fg = fg_color,font=("lucida",12,"bold"),bd = 7,relief = GROOVE,command = self.clear)
        clear_btn.grid(row = 2,column = 5,ipadx = 20,padx = 30)

        #======================
        exit_btn = Button(F4,text = "Sortir",bg = bg_color,fg = fg_color,font=("lucida",12,"bold"),bd = 7,relief = GROOVE,command = self.exit)
        exit_btn.grid(row = 1,column = 7,ipadx = 20)
        #============================
        pdf_gen = Button(F4,text = "PDF ",bg = bg_color,fg = fg_color,font=("lucida",12,"bold"),bd = 7,relief = GROOVE, command = self.gen_pdf)
        pdf_gen.grid(row = 2,column = 4,ipadx = 20)

#Function to get total prices
    def total(self):
        #=================Prix total patisserie française
        self.total_fran_prix = (
            (self.PARIS_BREST.get() * 40)+
            (self.MILLEFEUILLE.get() * 140)+
            (self.OPERA.get() * 240)+
            (self.FRAISIER.get() * 340)+
            (self.ECLAIR.get() * 260)
        )
        self.total_fran.set("Dt. "+str(self.total_fran_prix))
        self.tax_fran.set("Dt. "+str(round(self.total_fran_prix*0.05)))
        #====================prix total tunisienne
        self.total_tuni_prix= (
            (self.Zlabia.get()*100)+
            (self.Makroud.get() * 180)+
            (self.Bambalouni.get() * 80)+
            (self.BAK.get() *80)+
            (self.Bjawia.get() * 170)

        )
        self.total_tuni.set("Dt. "+str(self.total_tuni_prix))
        self.tax_tuni.set("Dt. "+str(round(self.total_tuni_prix*0.05)))
        #======================Prix des autres
        self.total_autre_prix= (
            (self.jus.get() * 20)+
            (self.citronnade.get() * 50)+
            (self.boisson_gazeuse.get() * 60)+
            (self.eau.get() * 20)+
            (self.biscuits.get() * 20)
        )
        self.total_autre.set("Dt. "+str(self.total_autre_prix))
        self.tax_autre.set("Dt. "+str(round(self.total_autre_prix*0.05)))


#Function For Text Area
    def welcome_soft(self):
        self.txt.delete('1.0',END)
        self.txt.insert(END,"  Bienvenue dans notre pâtisserie  \n")
        self.txt.insert(END,f"\nNumero de Ticket. : {str(self.no_tic_client.get())}")
        self.txt.insert(END,f"\nID client : {str(self.id_client.get())}")
        self.txt.insert(END,f"\ntel du client. : {str(self.tel_client.get())}")
        self.txt.insert(END,"\n===================================")
        self.txt.insert(END,"\nProduit          Qty         Prix")
        self.txt.insert(END,"\n===================================")


#Function to clear the bill area
    def clear(self):
        self.txt.delete('1.0',END)
    

#Add Product name , qty and price to bill area
    def bill_area(self):
        self.welcome_soft()
        if self.PARIS_BREST.get() != 0:
            self.txt.insert(END,f"\nPARISBREST         {self.PARIS_BREST.get()}           {self.PARIS_BREST.get() * 40}")
        if self.MILLEFEUILLE.get() != 0:
            self.txt.insert(END,f"\nMILLEFEUILLE        {self.MILLEFEUILLE.get()}           {self.MILLEFEUILLE.get() * 140}")
        if self.OPERA.get() != 0:
            self.txt.insert(END,f"\nOPERA         {self.OPERA.get()}           {self.OPERA.get() * 240}")
        if self.FRAISIER.get() != 0:
            self.txt.insert(END,f"\nFRAISIER        {self.FRAISIER.get()}           {self.FRAISIER.get() * 340}")
        if self.ECLAIR.get() != 0 :
            self.txt.insert(END,f"\nECLAIR       {self.ECLAIR.get()}           {self.ECLAIR.get() * 260}")
        if self.Zlabia.get() != 0:
            self.txt.insert(END,f"\nZlabia             {self.Zlabia.get()}           {self.Zlabia.get() * 100}")
        if self.Makroud.get() != 0:
            self.txt.insert(END,f"\nMakroud          {self.Makroud.get()}           {self.Makroud.get() * 180}")
        if self.Bambalouni.get() != 0:
            self.txt.insert(END,f"\nBambalouni              {self.Bambalouni.get()}           {self.Bambalouni.get() * 80}")
        if self.BAK.get() != 0:
            self.txt.insert(END,f"\nBAKLAWA eL BEY              {self.BAK.get()}           {self.BAK.get() * 80}")
        if self.Bjawia.get() != 0:
            self.txt.insert(END,f"\nBjawia          {self.Bjawia.get()}           {self.Bjawia.get() * 170}")
        if self.jus.get() != 0:
            self.txt.insert(END,f"\nJus             {self.jus.get()}           {self.jus.get() * 20}")
        if self.citronnade.get() != 0:
            self.txt.insert(END,f"\ncitronnade            {self.citronnade.get()}           {self.citronnade.get() * 50}")
        if self.boisson_gazeuse.get() != 0:
            self.txt.insert(END,f"\nboisson gazeuse             {self.boisson_gazeuse.get()}           {self.boisson_gazeuse.get() * 60}")
        if self.eau.get() != 0:
            self.txt.insert(END,f"\nEAU            {self.eau.get()}           {self.eau.get() * 20}")
        if self.biscuits.get() != 0:
            self.txt.insert(END,f"\nBiscuits          {self.biscuits.get()}           {self.biscuits.get() * 20}")
        self.txt.insert(END,"\n===================================")
        self.txt.insert(END,f"\n                      Total : {self.total_fran_prix+self.total_tuni_prix+self.total_autre_prix+self.total_fran_prix * 0.05+self.total_tuni_prix * 0.05+self.total_autre_prix * 0.05}")
        return(self.txt)
    def gen_pdf(self ):
        filename='ticket_numero_'+str(self.no_tic_client.get())+'.pdf'
        documenttitle ="ticket"
        lines = "\n==================================="
        lines_list =[]
        lines_list.append("  Bienvenue dans notre pâtisserie  \n")
        lines_list.append(f"\nNumero de Ticket. : {str(self.no_tic_client.get())}")
        lines_list.append(f"\nID client : {str(self.id_client.get())}")
        lines_list.append(f"\ntel du client. : {str(self.tel_client.get())}")
        lines_list.append("\n===================================")
        lines_list.append("\nProduit          Qty         Prix")
        lines_list.append("\n===================================")
        if self.PARIS_BREST.get() != 0:
            lines_list.append(f"\nPARISBREST         {self.PARIS_BREST.get()}           {self.PARIS_BREST.get() * 40}")
        if self.MILLEFEUILLE.get() != 0:
            lines_list.append(f"\nMILLEFEUILLE        {self.MILLEFEUILLE.get()}           {self.MILLEFEUILLE.get() * 140}")
        if self.OPERA.get() != 0:
            lines_list.append(f"\nOPERA         {self.OPERA.get()}           {self.OPERA.get() * 240}")
        if self.FRAISIER.get() != 0:
            lines_list.append(f"\nFRAISIER        {self.FRAISIER.get()}           {self.FRAISIER.get() * 340}")
        if self.ECLAIR.get() != 0 :
            lines_list.append(f"\nECLAIR       {self.ECLAIR.get()}           {self.ECLAIR.get() * 260}")
        if self.Zlabia.get() != 0:
            lines_list.append(f"\nZlabia             {self.Zlabia.get()}           {self.Zlabia.get() * 100}")
        if self.Makroud.get() != 0:
            lines_list.append(f"\nMakroud          {self.Makroud.get()}           {self.Makroud.get() * 180}")
        if self.Bambalouni.get() != 0:
            lines_list.append(f"\nBambalouni              {self.Bambalouni.get()}           {self.Bambalouni.get() * 80}")
        if self.BAK.get() != 0:
            lines_list.append(f"\nBAKLAWA eL BEY              {self.BAK.get()}           {self.BAK.get() * 80}")
        if self.Bjawia.get() != 0:
            lines_list.append(f"\nBjawia          {self.Bjawia.get()}           {self.Bjawia.get() * 170}")
        if self.jus.get() != 0:
            lines_list.append(f"\nJus             {self.jus.get()}           {self.jus.get() * 20}")
        if self.citronnade.get() != 0:
            lines_list.append(f"\ncitronnade            {self.citronnade.get()}           {self.citronnade.get() * 50}")
        if self.boisson_gazeuse.get() != 0:
            lines_list.append(f"\nboisson gazeuse             {self.boisson_gazeuse.get()}           {self.boisson_gazeuse.get() * 60}")
        if self.eau.get() != 0:
            lines_list.append(f"\nEAU            {self.eau.get()}           {self.eau.get() * 20}")
        if self.biscuits.get() != 0:
            lines_list.append(f"\nBiscuits          {self.biscuits.get()}           {self.biscuits.get() * 20}")
        lines_list.append("\n===================================")
        lines_list.append(f"\n                      Total : {self.total_fran_prix+self.total_tuni_prix+self.total_autre_prix+self.total_fran_prix * 0.05+self.total_tuni_prix * 0.05+self.total_autre_prix * 0.05}")
        maintitle =" TICKET PÂTISSERIE"
        endtitle ="Merci et Bienvenue"
        pdf = canvas.Canvas(filename)
        pdf.setTitle(documenttitle)
        pdf.drawCentredString(300,770,maintitle)
        pdf.drawString(10,10,endtitle)
        i =700
        for ele in lines_list:   
            pdf.drawString(100,i,ele)
            i-=10
        pdf.save()
        print("ticket ",  "PDF saved as "+filename)
    #Function to exit
    def exit(self):
        self.root.destroy()

    def add(self):
        E1 =caisse(int(self.id_client.get()),self.tel_client.get(),self.no_tic_client.get())
        print("caisse: ",E1.id_client)
        E1.ajoutercaisse()    

    #Function To Clear All Fields
    
    
    
    
    
root = Tk()
object = Ticket_App(root)
root.mainloop()
